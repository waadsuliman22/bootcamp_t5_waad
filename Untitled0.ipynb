# %% [markdown]
# <a href="https://colab.research.google.com/github/waadsuliman22/bootcamp_t5_waad/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#choose 3 months from data march, april, may

def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [210306, 210313, 210320, 210327, 210403, 210410, 210417, 210424, 210501, 210508, 210515, 210522, 210529]
turnstiles_df = get_data(week_nums)

# %%
turnstiles_df.head(20)
# Out:
#      C/A  ... EXITS
# 0   A002  ...                                            2570434
# 1   A002  ...                                            2570445
# 2   A002  ...                                            2570500
# 3   A002  ...                                            2570546
# 4   A002  ...                                            2570582
# 5   A002  ...                                            2570596
# 6   A002  ...                                            2570598
# 7   A002  ...                                            2570602
# 8   A002  ...                                            2570637
# 9   A002  ...                                            2570671
# 10  A002  ...                                            2570709
# 11  A002  ...                                            2570717
# 12  A002  ...                                            2570718
# 13  A002  ...                                            2570742
# ...

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
turnstiles_df.columns = [column.strip() for column in turnstiles_df.columns]

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
turnstiles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2717757 entries, 0 to 208911
# Data columns (total 11 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   C/A       object
#  1   UNIT      object
#  2   SCP       object
#  3   STATION   object
#  4   LINENAME  object
#  5   DIVISION  object
#  6   DATE      object
#  7   TIME      object
#  8   DESC      object
#  9   ENTRIES   int64
#  10  EXITS     int64
# dtypes: int64(2), object(9)
# memory usage: 248.8+ MB

# %%
turnstiles_df.isna()
# Out:
#           C/A   UNIT    SCP  STATION  ...   TIME   DESC  ENTRIES  EXITS
# 0       False  False  False    False  ...  False  False    False  False
# 1       False  False  False    False  ...  False  False    False  False
# 2       False  False  False    False  ...  False  False    False  False
# 3       False  False  False    False  ...  False  False    False  False
# 4       False  False  False    False  ...  False  False    False  False
# ...       ...    ...    ...      ...  ...    ...    ...      ...    ...
# 208907  False  False  False    False  ...  False  False    False  False
# 208908  False  False  False    False  ...  False  False    False  False
# 208909  False  False  False    False  ...  False  False    False  False
# 208910  False  False  False    False  ...  False  False    False  False
# 208911  False  False  False    False  ...  False  False    False  False
#
# [2717757 rows x 11 columns]

# %%
#turnstiles_daily = (turnstiles_df
 #                       .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE", "TIME"],as_index=False)
  #                      .ENTRIES.first())

# %%
#turnstiles_daily.head(20)

# %%
turnstiles_df["DATE"] = pd.to_datetime(turnstiles_df.DATE)

# %%
#choose a set of dates every 3 months 
df1=turnstiles_df.loc[turnstiles_df['DATE'].isin(["03/02/2021", "03/03/2021", "03/04/2021", "03/05/2021", "03/06/2021", "03/07/2021", "03/08/2021", "09/03/2021", "03/10/2021", "3/11/2021", "03/11/2021", "03/12/2021", "03/13/2021", "03/14/2021", "03/15/2021", "03/16/2021", "03/17/2021", "03/18/2021", "03/19/2021"])]

# %%
df1
# Out:
#           C/A  UNIT       SCP  ...     DESC  ENTRIES    EXITS
# 18       A002  R051  02-00-00  ...  REGULAR  7538409  2570969
# 19       A002  R051  02-00-00  ...  REGULAR  7538419  2570995
# 20       A002  R051  02-00-00  ...  REGULAR  7538469  2571124
# 21       A002  R051  02-00-00  ...  REGULAR  7538572  2571162
# 22       A002  R051  02-00-00  ...  REGULAR  7538821  2571195
# ...       ...   ...       ...  ...      ...      ...      ...
# 207049  TRAM2  R469  00-05-01  ...  REGULAR     5554      544
# 207050  TRAM2  R469  00-05-01  ...  REGULAR     5554      544
# 207051  TRAM2  R469  00-05-01  ...  REGULAR     5554      544
# 207052  TRAM2  R469  00-05-01  ...  REGULAR     5554      544
# 207053  TRAM2  R469  00-05-01  ...  REGULAR     5554      544
#
# [505946 rows x 11 columns]

# %%
df1.sort_values(['DATE'],ascending=True)
# Out:
#           C/A  UNIT       SCP  ...     DESC     ENTRIES       EXITS
# 18       A002  R051  02-00-00  ...  REGULAR     7538409     2570969
# 49376    N035  R334  00-00-00  ...  REGULAR    14249748     8809707
# 49375    N035  R334  00-00-00  ...  REGULAR    14249747     8809705
# 135082   R116  R030  00-06-02  ...  REGULAR     8751144     9404921
# 135083   R116  R030  00-06-02  ...  REGULAR     8751189     9405020
# ...       ...   ...       ...  ...      ...         ...         ...
# 157204   R230  R143  02-00-01  ...  REGULAR  1174478613  1392672872
# 157205   R230  R143  02-00-01  ...  REGULAR  1174478613  1392672872
# 157206   R230  R143  02-00-01  ...  REGULAR  1174478613  1392672872
# 157208   R230  R143  02-00-01  ...  REGULAR  1174478613  1392672872
# 207053  TRAM2  R469  00-05-01  ...  REGULAR        5554         544
#
# [505946 rows x 11 columns]

# %% [markdown]
# df1

# %%
#choose a set of dates from the secend months 
df2=turnstiles_df.loc[turnstiles_df['DATE'].isin(["04/02/2021", "04/03/2021", "04/04/2021", "04/05/2021", "04/05/2021", "04/06/2021", "04/07/2021", "04/08/2021", "04/09/2021", "04/10/2021", "04/11/2021", "04/12/2021", "04/13/2021", "04/14/2021", "04/15/2021", "04/16/2021", "04/17/2021", "04/18/2021", "04/19/2021"])]

# %%
df2
# Out:
#           C/A  UNIT       SCP  ...        DESC  ENTRIES    EXITS
# 36       A002  R051  02-00-00  ...  RECOVR AUD  7552051  2577948
# 37       A002  R051  02-00-00  ...  RECOVR AUD  7552051  2577950
# 38       A002  R051  02-00-00  ...  RECOVR AUD  7552051  2577985
# 39       A002  R051  02-00-00  ...     REGULAR  7552051  2578081
# 40       A002  R051  02-00-00  ...     REGULAR  7552051  2578132
# ...       ...   ...       ...  ...         ...      ...      ...
# 209076  TRAM2  R469  00-05-01  ...     REGULAR     5554      547
# 209077  TRAM2  R469  00-05-01  ...     REGULAR     5554      547
# 209078  TRAM2  R469  00-05-01  ...     REGULAR     5554      547
# 209079  TRAM2  R469  00-05-01  ...     REGULAR     5554      547
# 209080  TRAM2  R469  00-05-01  ...     REGULAR     5554      547
#
# [538674 rows x 11 columns]

# %%
##choose a set of dates from the 3rd months 
df3=turnstiles_df.loc[turnstiles_df['DATE'].isin(["05/02/2021", "05/03/2021", "05/04/2021", "05/05/2021", "05/05/2021", "05/06/2021", "05/07/2021", "05/08/2021", "05/09/2021", "05/10/2021", "05/11/2021", "05/12/2021", "05/13/2021", "05/14/2021", "05/15/2021", "05/16/2021", "05/17/2021", "05/18/2021", "05/19/2021"])]

# %%
df3
# Out:
#           C/A  UNIT       SCP  ...     DESC  ENTRIES    EXITS
# 6        A002  R051  02-00-00  ...  REGULAR  7565050  2584544
# 7        A002  R051  02-00-00  ...  REGULAR  7565057  2584544
# 8        A002  R051  02-00-00  ...  REGULAR  7565063  2584563
# 9        A002  R051  02-00-00  ...  REGULAR  7565093  2584598
# 10       A002  R051  02-00-00  ...  REGULAR  7565173  2584627
# ...       ...   ...       ...  ...      ...      ...      ...
# 209298  TRAM2  R469  00-05-01  ...  REGULAR     5554      552
# 209299  TRAM2  R469  00-05-01  ...  REGULAR     5554      553
# 209300  TRAM2  R469  00-05-01  ...  REGULAR     5554      553
# 209301  TRAM2  R469  00-05-01  ...  REGULAR     5554      553
# 209302  TRAM2  R469  00-05-01  ...  REGULAR     5554      553
#
# [537889 rows x 11 columns]

# %%
#join  the 3 months 
list = [df1, df2, df3 ]
new_df = pd.concat(list)

# %%
new_df.head()
# Out:
#      C/A  UNIT       SCP STATION  ...      TIME     DESC  ENTRIES    EXITS
# 18  A002  R051  02-00-00   59 ST  ...  03:00:00  REGULAR  7538409  2570969
# 19  A002  R051  02-00-00   59 ST  ...  07:00:00  REGULAR  7538419  2570995
# 20  A002  R051  02-00-00   59 ST  ...  11:00:00  REGULAR  7538469  2571124
# 21  A002  R051  02-00-00   59 ST  ...  15:00:00  REGULAR  7538572  2571162
# 22  A002  R051  02-00-00   59 ST  ...  19:00:00  REGULAR  7538821  2571195
#
# [5 rows x 11 columns]

# %%
new_df['Turnstile'] = new_df['C/A'] + new_df['UNIT'] + new_df['SCP'] + new_df['STATION']

# %%
# find total entries/exits
grouped_time=new_df.copy()
grouped_time["PREV_TIME"] = new_df.groupby(["Turnstile"]).TIME.shift(1)
grouped_time["PREV_EXITS"] = new_df.groupby(["Turnstile"]).EXITS.shift(1)
grouped_time["PREV_ENTRIES"] = new_df.groupby(["Turnstile"]).ENTRIES.shift(1)
grouped_time.tail()
# Out:
#           C/A  UNIT       SCP  ... PREV_TIME PREV_EXITS PREV_ENTRIES
# 209298  TRAM2  R469  00-05-01  ...  01:00:00      552.0       5554.0
# 209299  TRAM2  R469  00-05-01  ...  05:00:00      552.0       5554.0
# 209300  TRAM2  R469  00-05-01  ...  09:00:00      553.0       5554.0
# 209301  TRAM2  R469  00-05-01  ...  13:00:00      553.0       5554.0
# 209302  TRAM2  R469  00-05-01  ...  17:00:00      553.0       5554.0
#
# [5 rows x 15 columns]

# %%
#drop first row of each turnstile b/c of shift down
grouped_time.dropna(subset=["PREV_ENTRIES"], axis=0, inplace=True)
grouped_time.head()
# Out:
#      C/A  UNIT       SCP  ... PREV_TIME PREV_EXITS PREV_ENTRIES
# 19  A002  R051  02-00-00  ...  03:00:00  2570969.0    7538409.0
# 20  A002  R051  02-00-00  ...  07:00:00  2570995.0    7538419.0
# 21  A002  R051  02-00-00  ...  11:00:00  2571124.0    7538469.0
# 22  A002  R051  02-00-00  ...  15:00:00  2571162.0    7538572.0
# 23  A002  R051  02-00-00  ...  19:00:00  2571195.0    7538821.0
#
# [5 rows x 15 columns]

# %%
#Remove counter errors from total entries/exits that occur from counters resetting 
def get_daily_counts_exits(row, max_counter):
    counter_ex = row["EXITS"] - row["PREV_EXITS"]
    if counter_ex < 0:
        counter_ex = -counter_ex
    if counter_ex > max_counter:
## Maybe counter was reset to 0? 
        #print(row["EXITS"], row["PREV_EXITS"])
        counter_ex = min(row["EXITS"], row["PREV_EXITS"])
    if counter_ex > max_counter:
        return 0
    return counter_ex

# %%
def get_daily_counts_entries(row, max_counter):
    counter_ent = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter_ent < 0:
        counter_ent = -counter_ent
    if counter_ent > max_counter:
# Maybe counter was reset to 0? 
        #print(row["ENTRIES"], row["PREV_ENTRIES"])
        counter_ent = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter_ent > max_counter:
        return 0
    return counter_ent

# %%
grouped_time["TOTAL_ENTRIES"] = grouped_time.apply(get_daily_counts_entries, axis=1, max_counter=100000)
grouped_time["TOTAL_EXITS"] = grouped_time.apply(get_daily_counts_exits, axis=1, max_counter=100000)
grouped_time.describe()
# Out:
#             ENTRIES         EXITS  ...  TOTAL_ENTRIES   TOTAL_EXITS
# count  1.577471e+06  1.577471e+06  ...   1.577471e+06  1.577471e+06
# mean   4.186442e+07  3.362956e+07  ...   7.990785e+01  8.770246e+01
# std    2.182010e+08  1.932623e+08  ...   5.320752e+02  6.660301e+02
# min    0.000000e+00  0.000000e+00  ...   0.000000e+00  0.000000e+00
# 25%    2.186835e+05  9.254300e+04  ...   2.000000e+00  4.000000e+00
# 50%    1.460082e+06  8.741000e+05  ...   2.200000e+01  2.300000e+01
# 75%    6.124892e+06  4.026442e+06  ...   7.400000e+01  7.400000e+01
# max    2.147432e+09  2.123008e+09  ...   9.506800e+04  9.917000e+04
#
# [8 rows x 6 columns]

# %%
import numpy as np
from scipy import stats
import math

# %%
#find total entries & exits
grouped_time = grouped_time[(np.abs(stats.zscore(grouped_time["TOTAL_ENTRIES"])) < 3)] #filtering
grouped_time = grouped_time[(np.abs(stats.zscore(grouped_time["TOTAL_EXITS"])) < 3)] #filtering
grouped_time["TOTAL_TRAFFIC"] = grouped_time["TOTAL_EXITS"] + grouped_time["TOTAL_ENTRIES"]
grouped_time.head()
# Out:
#      C/A  UNIT       SCP  ... TOTAL_ENTRIES TOTAL_EXITS TOTAL_TRAFFIC
# 19  A002  R051  02-00-00  ...          10.0        26.0          36.0
# 20  A002  R051  02-00-00  ...          50.0       129.0         179.0
# 21  A002  R051  02-00-00  ...         103.0        38.0         141.0
# 22  A002  R051  02-00-00  ...         249.0        33.0         282.0
# 23  A002  R051  02-00-00  ...         105.0        16.0         121.0
#
# [5 rows x 18 columns]

# %%
#find total entries 
dataFrame = grouped_time.groupby(['STATION']).TOTAL_ENTRIES.sum().reset_index().sort_values("TOTAL_ENTRIES",ascending =False ).head(379)
dataFrame
# Out:
#              STATION  TOTAL_ENTRIES
# 61    34 ST-PENN STA      1736464.0
# 59   34 ST-HERALD SQ      1429454.0
# 110            86 ST      1389723.0
# 9             125 ST      1307447.0
# 233  GRD CNTRL-42 ST      1256384.0
# ..               ...            ...
# 144      BEACH 44 ST        14582.0
# 332  ROCKAWAY PARK B        13517.0
# 148      BEACH 98 ST         8415.0
# 162    BROAD CHANNEL         7727.0
# 141     BEACH 105 ST         4241.0
#
# [378 rows x 2 columns]

# %%
#find the station 'PENNSYLVANIA AV' & total traffic 
#because The most famous stations in New York on finals days
m = (dataFrame['STATION'] == 'PENNSYLVANIA AV')
dataFrame[m].head()
# Out:
#              STATION  TOTAL_TRAFFIC
# 319  PENNSYLVANIA AV       153658.0

# %%
#plot the total entries 
import matplotlib.pyplot as plt
x = ["34 ST-PENN STA","34 ST-HERALD SQ","86 ST","125 ST","GRD CNTRL-42 ST"]
plt.bar(x, dataFrame["TOTAL_ENTRIES"])
# Out:
# <BarContainer object of 5 artists>

# %%
dataFrame = grouped_time.groupby(['STATION']).TOTAL_TRAFFIC.sum().reset_index().sort_values("TOTAL_TRAFFIC",ascending =False ).head()

# %%
##plot the total traffic 
import matplotlib.pyplot as plt
x = ["34 ST-PENN STA","34 ST-HERALD SQ","86 ST","125 ST","GRD CNTRL-42 ST"]
plt.bar(x, dataFrame["TOTAL_TRAFFIC"])
# Out:
# <BarContainer object of 5 artists>
